# %% [markdown]
# <a href="https://colab.research.google.com/github/bdgroves/desert-ecostats/blob/main/Bdgroves_xarray.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Multi-dimensional Data Analysis with Xarray
#
# ## Introduction
#
# ## Learning Objectives
#
# ## Understanding Xarray's Data Model
#
# ### Core Data Structures
#
# ### Why This Structure Matters
#
# ## Setting Up Your Environment
#
# ### Installing Required Packages

# %%
# %pip install xarray pooch pygis
# Out:
# Requirement already satisfied: xarray in /usr/local/lib/python3.11/dist-packages (2025.3.1)
# Requirement already satisfied: pooch in /usr/local/lib/python3.11/dist-packages (1.8.2)
# Collecting pygis
#   Downloading pygis-0.10.1-py2.py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.11/dist-packages (from xarray) (2.0.2)
# Requirement already satisfied: packaging>=23.2 in /usr/local/lib/python3.11/dist-packages (from xarray) (24.2)
# Requirement already satisfied: pandas>=2.1 in /usr/local/lib/python3.11/dist-packages (from xarray) (2.2.2)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from pooch) (4.3.8)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from pooch) (2.32.3)
# Collecting bash_kernel (from pygis)
#   Downloading bash_kernel-0.10.0-py2.py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: duckdb in /usr/local/lib/python3.11/dist-packages (from pygis) (1.2.2)
# Collecting duckdb-engine (from pygis)
#   Downloading duckdb_engine-0.17.0-py3-none-any.whl.metadata (8.4 kB)
# Collecting ffmpeg-python (from pygis)
#   Downloading ffmpeg_python-0.2.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting geeadd (from pygis)
#   Downloading geeadd-1.2.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: geemap>=0.35.3 in /usr/local/lib/python3.11/dist-packages (from pygis) (0.35.3)
# Requirement already satisfied: geopandas in /usr/local/lib/python3.11/dist-packages (from pygis) (1.0.1)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.11/dist-packages (from pygis) (6.17.1)
# Collecting jupysql (from pygis)
#   Downloading jupysql-0.11.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting jupyter-server-proxy (from pygis)
#   Downloading jupyter_server_proxy-4.4.0-py3-none-any.whl.metadata (8.7 kB)
# Collecting leafmap>=0.48.0 (from pygis)
#   Downloading leafmap-0.48.6-py2.py3-none-any.whl.metadata (16 kB)
# Collecting mapclassify (from pygis)
#   Downloading mapclassify-2.9.0-py3-none-any.whl.metadata (3.1 kB)
# Collecting maplibre (from pygis)
#   Downloading maplibre-0.3.4-py3-none-any.whl.metadata (3.9 kB)
# Collecting mapwidget (from pygis)
#   Downloading mapwidget-0.2.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting planetary-computer (from pygis)
#   Downloading planetary_computer-1.0.0-py3-none-any.whl.metadata (7.4 kB)
# Collecting pmtiles (from pygis)
#   Downloading pmtiles-3.4.1.tar.gz (13 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: shapely in /usr/local/lib/python3.11/dist-packages (from pygis) (2.1.1)
# Collecting solara (from pygis)
#   Downloading solara-1.49.0-py3-none-any.whl.metadata (10 kB)
# Collecting voila (from pygis)
#   Downloading voila-0.5.8-py3-none-any.whl.metadata (9.5 kB)
# Collecting voila-topbar (from pygis)
#   Downloading voila_topbar-0.1.1-py3-none-any.whl.metadata (5.8 kB)
# Collecting whiteboxgui (from pygis)
#   Downloading whiteboxgui-2.3.0-py2.py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: bqplot in /usr/local/lib/python3.11/dist-packages (from geemap>=0.35.3->pygis) (0.12.45)
# Requirement already satisfied: colour in /usr/local/lib/python3.11/dist-packages (from geemap>=0.35.3->pygis) (0.1.5)
# Requirement already satisfied: earthengine-api>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from geemap>=0.35.3->pygis) (1.5.21)
# Requirement already satisfied: eerepr>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from geemap>=0.35.3->pygis) (0.1.2)
# Requirement already satisfied: folium>=0.17.0 in /usr/local/lib/python3.11/dist-packages (from geemap>=0.35.3->pygis) (0.19.7)
# Requirement already satisfied: geocoder in /usr/local/lib/python3.11/dist-packages (from geemap>=0.35.3->pygis) (1.38.1)
# Requirement already satisfied: ipyevents in /usr/local/lib/python3.11/dist-packages (from geemap>=0.35.3->pygis) (2.0.2)
# Requirement already satisfied: ipyfilechooser>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from geemap>=0.35.3->pygis) (0.6.0)
# Requirement already satisfied: ipyleaflet>=0.19.2 in /usr/local/lib/python3.11/dist-packages (from geemap>=0.35.3->pygis) (0.20.0)
# Requirement already satisfied: ipytree in /usr/local/lib/python3.11/dist-packages (from geemap>=0.35.3->pygis) (0.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from geemap>=0.35.3->pygis) (3.10.0)
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (from geemap>=0.35.3->pygis) (5.24.1)
# Requirement already satisfied: pyperclip in /usr/local/lib/python3.11/dist-packages (from geemap>=0.35.3->pygis) (1.9.0)
# Requirement already satisfied: pyshp>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from geemap>=0.35.3->pygis) (2.3.1)
# Requirement already satisfied: python-box in /usr/local/lib/python3.11/dist-packages (from geemap>=0.35.3->pygis) (7.3.2)
# Requirement already satisfied: scooby in /usr/local/lib/python3.11/dist-packages (from geemap>=0.35.3->pygis) (0.10.1)
# Collecting anywidget (from leafmap>=0.48.0->pygis)
#   Downloading anywidget-0.9.18-py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: gdown in /usr/local/lib/python3.11/dist-packages (from leafmap>=0.48.0->pygis) (5.2.0)
# Collecting geojson (from leafmap>=0.48.0->pygis)
#   Downloading geojson-3.2.0-py3-none-any.whl.metadata (16 kB)
# Collecting ipyvuetify (from leafmap>=0.48.0->pygis)
#   Downloading ipyvuetify-1.11.2-py2.py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.11/dist-packages (from leafmap>=0.48.0->pygis) (7.7.1)
# Collecting pystac-client (from leafmap>=0.48.0->pygis)
#   Downloading pystac_client-0.8.6-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.11/dist-packages (from leafmap>=0.48.0->pygis) (2025.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.1->xarray) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.1->xarray) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.1->xarray) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch) (2025.6.15)
# Requirement already satisfied: pexpect>=4.0 in /usr/local/lib/python3.11/dist-packages (from bash_kernel->pygis) (4.9.0)
# Collecting filetype (from bash_kernel->pygis)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: sqlalchemy>=1.3.22 in /usr/local/lib/python3.11/dist-packages (from duckdb-engine->pygis) (2.0.41)
# Requirement already satisfied: future in /usr/local/lib/python3.11/dist-packages (from ffmpeg-python->pygis) (1.0.0)
# Collecting colorama>=0.4.6 (from geeadd->pygis)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Collecting jsbeautifier>=1.15.1 (from geeadd->pygis)
#   Downloading jsbeautifier-1.15.4-py3-none-any.whl.metadata (374 bytes)
# Collecting logzero>=1.7.0 (from geeadd->pygis)
#   Downloading logzero-1.7.0-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: setuptools>=65.5.0 in /usr/local/lib/python3.11/dist-packages (from geeadd->pygis) (75.2.0)
# Requirement already satisfied: tqdm>=4.66.5 in /usr/local/lib/python3.11/dist-packages (from geeadd->pygis) (4.67.1)
# Requirement already satisfied: beautifulsoup4>=4.9.0 in /usr/local/lib/python3.11/dist-packages (from geeadd->pygis) (4.13.4)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.11/dist-packages (from geopandas->pygis) (0.11.0)
# Requirement already satisfied: pyproj>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from geopandas->pygis) (3.7.1)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.11/dist-packages (from ipykernel->pygis) (1.8.0)
# Requirement already satisfied: ipython>=7.23.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel->pygis) (7.34.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.11/dist-packages (from ipykernel->pygis) (6.1.12)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel->pygis) (0.1.7)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.11/dist-packages (from ipykernel->pygis) (1.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ipykernel->pygis) (5.9.5)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.11/dist-packages (from ipykernel->pygis) (24.0.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel->pygis) (6.4.2)
# Requirement already satisfied: traitlets>=5.1.0 in /usr/local/lib/python3.11/dist-packages (from ipykernel->pygis) (5.7.1)
# Requirement already satisfied: prettytable>=3.12.0 in /usr/local/lib/python3.11/dist-packages (from jupysql->pygis) (3.16.0)
# Requirement already satisfied: sqlparse in /usr/local/lib/python3.11/dist-packages (from jupysql->pygis) (0.5.3)
# Requirement already satisfied: ipython-genutils>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from jupysql->pygis) (0.2.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from jupysql->pygis) (3.1.6)
# Requirement already satisfied: sqlglot>=11.3.7 in /usr/local/lib/python3.11/dist-packages (from jupysql->pygis) (25.20.2)
# Collecting jupysql-plugin>=0.4.2 (from jupysql->pygis)
#   Downloading jupysql_plugin-0.4.5-py3-none-any.whl.metadata (7.8 kB)
# Collecting ploomber-core>=0.2.7 (from jupysql->pygis)
#   Downloading ploomber_core-0.2.26-py3-none-any.whl.metadata (527 bytes)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from jupyter-server-proxy->pygis) (3.11.15)
# Collecting jupyter-server>=1.24.0 (from jupyter-server-proxy->pygis)
#   Downloading jupyter_server-2.16.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting simpervisor>=1.0.0 (from jupyter-server-proxy->pygis)
#   Downloading simpervisor-1.0.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: networkx>=3.2 in /usr/local/lib/python3.11/dist-packages (from mapclassify->pygis) (3.5)
# Requirement already satisfied: scikit-learn>=1.4 in /usr/local/lib/python3.11/dist-packages (from mapclassify->pygis) (1.6.1)
# Requirement already satisfied: scipy>=1.12 in /usr/local/lib/python3.11/dist-packages (from mapclassify->pygis) (1.15.3)
# Requirement already satisfied: branca in /usr/local/lib/python3.11/dist-packages (from maplibre->pygis) (0.8.1)
# Collecting eval-type-backport (from maplibre->pygis)
#   Downloading eval_type_backport-0.2.2-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: pydantic>=2.5.3 in /usr/local/lib/python3.11/dist-packages (from maplibre->pygis) (2.11.7)
# Requirement already satisfied: click>=7.1 in /usr/local/lib/python3.11/dist-packages (from planetary-computer->pygis) (8.2.1)
# Collecting pystac>=1.0.0 (from planetary-computer->pygis)
#   Downloading pystac-1.13.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting python-dotenv (from planetary-computer->pygis)
#   Downloading python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# Collecting solara-server==1.49.0 (from solara-server[dev,starlette]==1.49.0->solara->pygis)
#   Downloading solara_server-1.49.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting solara-ui==1.49.0 (from solara-ui[all]==1.49.0->solara->pygis)
#   Downloading solara_ui-1.49.0-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from solara-server==1.49.0->solara-server[dev,starlette]==1.49.0->solara->pygis) (3.18.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.11/dist-packages (from solara-server==1.49.0->solara-server[dev,starlette]==1.49.0->solara->pygis) (5.10.4)
# Collecting rich-click (from solara-server==1.49.0->solara-server[dev,starlette]==1.49.0->solara->pygis)
#   Downloading rich_click-1.8.9-py3-none-any.whl.metadata (7.9 kB)
# Collecting watchdog (from solara-server[dev,starlette]==1.49.0->solara->pygis)
#   Downloading watchdog-6.0.0-py3-none-manylinux2014_x86_64.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 3.8 MB/s eta 0:00:00
# Collecting watchfiles (from solara-server[dev,starlette]==1.49.0->solara->pygis)
#   Downloading watchfiles-1.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: starlette in /usr/local/lib/python3.11/dist-packages (from solara-server[dev,starlette]==1.49.0->solara->pygis) (0.46.2)
# Requirement already satisfied: uvicorn in /usr/local/lib/python3.11/dist-packages (from solara-server[dev,starlette]==1.49.0->solara->pygis) (0.34.3)
# Requirement already satisfied: websockets in /usr/local/lib/python3.11/dist-packages (from solara-server[dev,starlette]==1.49.0->solara->pygis) (15.0.1)
# Requirement already satisfied: humanize in /usr/local/lib/python3.11/dist-packages (from solara-ui==1.49.0->solara-ui[all]==1.49.0->solara->pygis) (4.12.3)
# Collecting ipyvue>=1.9.0 (from solara-ui==1.49.0->solara-ui[all]==1.49.0->solara->pygis)
#   Downloading ipyvue-1.11.2-py2.py3-none-any.whl.metadata (1.1 kB)
# Collecting reacton>=1.9 (from solara-ui==1.49.0->solara-ui[all]==1.49.0->solara->pygis)
#   Downloading reacton-1.9.1-py2.py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.11/dist-packages (from solara-ui[all]==1.49.0->solara->pygis) (5.5.2)
# Requirement already satisfied: markdown in /usr/local/lib/python3.11/dist-packages (from solara-ui[all]==1.49.0->solara->pygis) (3.8.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from solara-ui[all]==1.49.0->solara->pygis) (11.2.1)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from solara-ui[all]==1.49.0->solara->pygis) (2.19.2)
# Collecting pymdown-extensions (from solara-ui[all]==1.49.0->solara->pygis)
#   Downloading pymdown_extensions-10.16-py3-none-any.whl.metadata (3.0 kB)
# Collecting jupyter-client>=6.1.12 (from ipykernel->pygis)
#   Downloading jupyter_client-8.6.3-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: jupyter-core>=4.11.0 in /usr/local/lib/python3.11/dist-packages (from voila->pygis) (5.8.1)
# Collecting jupyterlab-server<3,>=2.3.0 (from voila->pygis)
#   Downloading jupyterlab_server-2.27.3-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: nbclient>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from voila->pygis) (0.10.2)
# Requirement already satisfied: nbconvert<8,>=6.4.5 in /usr/local/lib/python3.11/dist-packages (from voila->pygis) (7.16.6)
# Collecting whitebox (from whiteboxgui->pygis)
#   Downloading whitebox-2.3.6-py2.py3-none-any.whl.metadata (11 kB)
# Collecting psygnal>=0.8.1 (from anywidget->leafmap>=0.48.0->pygis)
#   Downloading psygnal-0.13.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.0 kB)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.11/dist-packages (from anywidget->leafmap>=0.48.0->pygis) (4.14.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.9.0->geeadd->pygis) (2.7)
# Requirement already satisfied: google-cloud-storage in /usr/local/lib/python3.11/dist-packages (from earthengine-api>=1.0.0->geemap>=0.35.3->pygis) (2.19.0)
# Requirement already satisfied: google-api-python-client>=1.12.1 in /usr/local/lib/python3.11/dist-packages (from earthengine-api>=1.0.0->geemap>=0.35.3->pygis) (2.173.0)
# Requirement already satisfied: google-auth>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from earthengine-api>=1.0.0->geemap>=0.35.3->pygis) (2.38.0)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.11/dist-packages (from earthengine-api>=1.0.0->geemap>=0.35.3->pygis) (0.2.0)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in /usr/local/lib/python3.11/dist-packages (from earthengine-api>=1.0.0->geemap>=0.35.3->pygis) (0.22.0)
# Requirement already satisfied: jupyter-leaflet<0.21,>=0.20 in /usr/local/lib/python3.11/dist-packages (from ipyleaflet>=0.19.2->geemap>=0.35.3->pygis) (0.20.0)
# Requirement already satisfied: traittypes<3,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from ipyleaflet>=0.19.2->geemap>=0.35.3->pygis) (0.2.1)
# Collecting jedi>=0.16 (from ipython>=7.23.1->ipykernel->pygis)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel->pygis) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel->pygis) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel->pygis) (3.0.51)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel->pygis) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets->leafmap>=0.48.0->pygis) (3.6.10)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets->leafmap>=0.48.0->pygis) (3.0.15)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->jupysql->pygis) (3.0.2)
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.11/dist-packages (from jsbeautifier>=1.15.1->geeadd->pygis) (1.17.0)
# Collecting editorconfig>=0.12.2 (from jsbeautifier>=1.15.1->geeadd->pygis)
#   Downloading editorconfig-0.17.1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: anyio>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->pygis) (4.9.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /usr/local/lib/python3.11/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->pygis) (25.1.0)
# Collecting jupyter-events>=0.11.0 (from jupyter-server>=1.24.0->jupyter-server-proxy->pygis)
#   Downloading jupyter_events-0.12.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting jupyter-server-terminals>=0.4.4 (from jupyter-server>=1.24.0->jupyter-server-proxy->pygis)
#   Downloading jupyter_server_terminals-0.5.3-py3-none-any.whl.metadata (5.6 kB)
# Collecting overrides>=5.0 (from jupyter-server>=1.24.0->jupyter-server-proxy->pygis)
#   Downloading overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: prometheus-client>=0.9 in /usr/local/lib/python3.11/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->pygis) (0.22.1)
# Requirement already satisfied: send2trash>=1.8.2 in /usr/local/lib/python3.11/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->pygis) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.11/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->pygis) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.11/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->pygis) (1.8.0)
# Requirement already satisfied: babel>=2.10 in /usr/local/lib/python3.11/dist-packages (from jupyterlab-server<3,>=2.3.0->voila->pygis) (2.17.0)
# Collecting json5>=0.9.0 (from jupyterlab-server<3,>=2.3.0->voila->pygis)
#   Downloading json5-0.12.0-py3-none-any.whl.metadata (36 kB)
# Requirement already satisfied: jsonschema>=4.18.0 in /usr/local/lib/python3.11/dist-packages (from jupyterlab-server<3,>=2.3.0->voila->pygis) (4.24.0)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert<8,>=6.4.5->voila->pygis) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.11/dist-packages (from nbconvert<8,>=6.4.5->voila->pygis) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.11/dist-packages (from nbconvert<8,>=6.4.5->voila->pygis) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.11/dist-packages (from nbconvert<8,>=6.4.5->voila->pygis) (3.1.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from nbconvert<8,>=6.4.5->voila->pygis) (1.5.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>=4.0->bash_kernel->pygis) (0.7.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from ploomber-core>=0.2.7->jupysql->pygis) (6.0.2)
# Collecting posthog (from ploomber-core>=0.2.7->jupysql->pygis)
#   Downloading posthog-6.0.0-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prettytable>=3.12.0->jupysql->pygis) (0.2.13)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.5.3->maplibre->pygis) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.5.3->maplibre->pygis) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.5.3->maplibre->pygis) (0.4.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.4->mapclassify->pygis) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.4->mapclassify->pygis) (3.6.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.3.22->duckdb-engine->pygis) (3.2.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->jupyter-server-proxy->pygis) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->jupyter-server-proxy->pygis) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->jupyter-server-proxy->pygis) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->jupyter-server-proxy->pygis) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->jupyter-server-proxy->pygis) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->jupyter-server-proxy->pygis) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->jupyter-server-proxy->pygis) (1.20.1)
# Requirement already satisfied: ratelim in /usr/local/lib/python3.11/dist-packages (from geocoder->geemap>=0.35.3->pygis) (0.1.6)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->geemap>=0.35.3->pygis) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->geemap>=0.35.3->pygis) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->geemap>=0.35.3->pygis) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->geemap>=0.35.3->pygis) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->geemap>=0.35.3->pygis) (3.2.3)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly->geemap>=0.35.3->pygis) (8.5.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio>=3.1.0->jupyter-server>=1.24.0->jupyter-server-proxy->pygis) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.11/dist-packages (from argon2-cffi>=21.1->jupyter-server>=1.24.0->jupyter-server-proxy->pygis) (21.2.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert<8,>=6.4.5->voila->pygis) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert<8,>=6.4.5->voila->pygis) (1.4.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client>=1.12.1->earthengine-api>=1.0.0->geemap>=0.35.3->pygis) (2.25.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client>=1.12.1->earthengine-api>=1.0.0->geemap>=0.35.3->pygis) (4.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth>=1.4.1->earthengine-api>=1.0.0->geemap>=0.35.3->pygis) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth>=1.4.1->earthengine-api>=1.0.0->geemap>=0.35.3->pygis) (4.9.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->pygis) (0.8.4)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.3.0->voila->pygis) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.3.0->voila->pygis) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.3.0->voila->pygis) (0.25.1)
# Collecting python-json-logger>=2.0.4 (from jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->pygis)
#   Downloading python_json_logger-3.3.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting rfc3339-validator (from jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->pygis)
#   Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting rfc3986-validator>=0.1.1 (from jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->pygis)
#   Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.11/dist-packages (from nbformat->solara-server==1.49.0->solara-server[dev,starlette]==1.49.0->solara->pygis) (2.21.1)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.11/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets->leafmap>=0.48.0->pygis) (6.5.7)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from google-cloud-storage->earthengine-api>=1.0.0->geemap>=0.35.3->pygis) (2.4.3)
# Requirement already satisfied: google-resumable-media>=2.7.2 in /usr/local/lib/python3.11/dist-packages (from google-cloud-storage->earthengine-api>=1.0.0->geemap>=0.35.3->pygis) (2.7.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.11/dist-packages (from google-cloud-storage->earthengine-api>=1.0.0->geemap>=0.35.3->pygis) (1.7.1)
# Collecting backoff>=1.10.0 (from posthog->ploomber-core>=0.2.7->jupysql->pygis)
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: distro>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from posthog->ploomber-core>=0.2.7->jupysql->pygis) (1.9.0)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown->leafmap>=0.48.0->pygis) (1.7.1)
# Requirement already satisfied: rich>=10.7 in /usr/local/lib/python3.11/dist-packages (from rich-click->solara-server==1.49.0->solara-server[dev,starlette]==1.49.0->solara->pygis) (13.9.4)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.11/dist-packages (from uvicorn->solara-server[dev,starlette]==1.49.0->solara->pygis) (0.16.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=1.0.0->geemap>=0.35.3->pygis) (1.70.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in /usr/local/lib/python3.11/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=1.0.0->geemap>=0.35.3->pygis) (5.29.5)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=1.0.0->geemap>=0.35.3->pygis) (1.26.1)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->pygis)
#   Downloading fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->pygis)
#   Downloading isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.11/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->pygis) (3.0.0)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->pygis)
#   Downloading uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->pygis) (24.11.1)
# Collecting jupyter-client>=6.1.12 (from ipykernel->pygis)
#   Downloading jupyter_client-7.4.9-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap>=0.48.0->pygis) (1.3.1)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.11/dist-packages (from jupyter-client>=6.1.12->ipykernel->pygis) (0.4)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->earthengine-api>=1.0.0->geemap>=0.35.3->pygis) (0.6.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.7->rich-click->solara-server==1.49.0->solara-server[dev,starlette]==1.49.0->solara->pygis) (3.0.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server>=1.24.0->jupyter-server-proxy->pygis) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server>=1.24.0->jupyter-server-proxy->pygis) (2.22)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.7->rich-click->solara-server==1.49.0->solara-server[dev,starlette]==1.49.0->solara->pygis) (0.1.2)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.11/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap>=0.48.0->pygis) (0.2.4)
# Collecting arrow>=0.15.0 (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->pygis)
#   Downloading arrow-1.3.0-py3-none-any.whl.metadata (7.5 kB)
# Collecting types-python-dateutil>=2.8.10 (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->pygis)
#   Downloading types_python_dateutil-2.9.0.20250516-py3-none-any.whl.metadata (2.1 kB)
# Downloading pygis-0.10.1-py2.py3-none-any.whl (3.4 kB)
# Downloading leafmap-0.48.6-py2.py3-none-any.whl (568 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 568.1/568.1 kB 12.8 MB/s eta 0:00:00
# Downloading bash_kernel-0.10.0-py2.py3-none-any.whl (616 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 617.0/617.0 kB 22.5 MB/s eta 0:00:00
# Downloading duckdb_engine-0.17.0-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.7/49.7 kB 3.6 MB/s eta 0:00:00
# Downloading ffmpeg_python-0.2.0-py3-none-any.whl (25 kB)
# Downloading geeadd-1.2.1-py3-none-any.whl (36 kB)
# Downloading jupysql-0.11.1-py3-none-any.whl (95 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.1/95.1 kB 7.6 MB/s eta 0:00:00
# Downloading jupyter_server_proxy-4.4.0-py3-none-any.whl (37 kB)
# Downloading mapclassify-2.9.0-py3-none-any.whl (286 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 286.7/286.7 kB 20.4 MB/s eta 0:00:00
# Downloading maplibre-0.3.4-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 50.7 MB/s eta 0:00:00
# Downloading mapwidget-0.2.0-py2.py3-none-any.whl (15 kB)
# Downloading planetary_computer-1.0.0-py3-none-any.whl (14 kB)
# Downloading solara-1.49.0-py3-none-any.whl (5.9 kB)
# Downloading solara_server-1.49.0-py3-none-any.whl (3.9 kB)
# Downloading solara_ui-1.49.0-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 52.7 MB/s eta 0:00:00
# Downloading voila-0.5.8-py3-none-any.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 93.6 MB/s eta 0:00:00
# Downloading voila_topbar-0.1.1-py3-none-any.whl (733 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 733.1/733.1 kB 37.9 MB/s eta 0:00:00
# Downloading whiteboxgui-2.3.0-py2.py3-none-any.whl (108 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.6/108.6 kB 9.3 MB/s eta 0:00:00
# Downloading anywidget-0.9.18-py3-none-any.whl (220 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.7/220.7 kB 16.7 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading ipyvuetify-1.11.2-py2.py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 98.8 MB/s eta 0:00:00
# Downloading jsbeautifier-1.15.4-py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.7/94.7 kB 7.3 MB/s eta 0:00:00
# Downloading jupysql_plugin-0.4.5-py3-none-any.whl (192 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 192.8/192.8 kB 14.1 MB/s eta 0:00:00
# Downloading jupyter_server-2.16.0-py3-none-any.whl (386 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.9/386.9 kB 27.2 MB/s eta 0:00:00
# Downloading jupyterlab_server-2.27.3-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.7/59.7 kB 4.8 MB/s eta 0:00:00
# Downloading logzero-1.7.0-py2.py3-none-any.whl (16 kB)
# Downloading ploomber_core-0.2.26-py3-none-any.whl (22 kB)
# Downloading pystac-1.13.0-py3-none-any.whl (206 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 206.8/206.8 kB 15.5 MB/s eta 0:00:00
# Downloading pystac_client-0.8.6-py3-none-any.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.4/41.4 kB 2.8 MB/s eta 0:00:00
# Downloading simpervisor-1.0.0-py3-none-any.whl (8.3 kB)
# Downloading eval_type_backport-0.2.2-py3-none-any.whl (5.8 kB)
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading geojson-3.2.0-py3-none-any.whl (15 kB)
# Downloading python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Downloading whitebox-2.3.6-py2.py3-none-any.whl (74 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.0/74.0 kB 6.1 MB/s eta 0:00:00
# Downloading editorconfig-0.17.1-py3-none-any.whl (16 kB)
# Downloading ipyvue-1.11.2-py2.py3-none-any.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 72.9 MB/s eta 0:00:00
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 68.4 MB/s eta 0:00:00
# Downloading json5-0.12.0-py3-none-any.whl (36 kB)
# Downloading jupyter_events-0.12.0-py3-none-any.whl (19 kB)
# Downloading jupyter_server_terminals-0.5.3-py3-none-any.whl (13 kB)
# Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Downloading psygnal-0.13.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (842 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 842.5/842.5 kB 46.0 MB/s eta 0:00:00
# Downloading reacton-1.9.1-py2.py3-none-any.whl (108 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.8/108.8 kB 8.9 MB/s eta 0:00:00
# Downloading posthog-6.0.0-py3-none-any.whl (104 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.9/104.9 kB 8.3 MB/s eta 0:00:00
# Downloading pymdown_extensions-10.16-py3-none-any.whl (266 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 266.1/266.1 kB 19.4 MB/s eta 0:00:00
# Downloading rich_click-1.8.9-py3-none-any.whl (36 kB)
# Downloading watchdog-6.0.0-py3-none-manylinux2014_x86_64.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 5.8 MB/s eta 0:00:00
# Downloading watchfiles-1.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (453 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 453.1/453.1 kB 27.9 MB/s eta 0:00:00
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading jupyter_client-7.4.9-py3-none-any.whl (133 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.5/133.5 kB 10.3 MB/s eta 0:00:00
# Downloading python_json_logger-3.3.0-py3-none-any.whl (15 kB)
# Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Downloading arrow-1.3.0-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 5.4 MB/s eta 0:00:00
# Downloading types_python_dateutil-2.9.0.20250516-py3-none-any.whl (14 kB)
# Building wheels for collected packages: pmtiles
#   Building wheel for pmtiles (setup.py) ... done
#   Created wheel for pmtiles: filename=pmtiles-3.4.1-py3-none-any.whl size=15820 sha256=adede9697244e354472ddcf34ddccee1e1b8adc9c130d67b196c2d19e28ff19c
#   Stored in directory: /root/.cache/pip/wheels/72/b2/97/f91fbdf248dc7a07a6b589ec68f0e00ecfc46c1dc5a75a1e6e
# Successfully built pmtiles
# Installing collected packages: pmtiles, logzero, filetype, whitebox, watchdog, voila-topbar, uri-template, types-python-dateutil, simpervisor, rfc3986-validator, rfc3339-validator, python-json-logger, python-dotenv, pymdown-extensions, psygnal, overrides, json5, jedi, geojson, fqdn, ffmpeg-python, eval-type-backport, editorconfig, colorama, backoff, watchfiles, pystac, posthog, jupyter-server-terminals, jupyter-client, jsbeautifier, duckdb-engine, arrow, rich-click, ploomber-core, maplibre, mapclassify, isoduration, jupysql-plugin, bash_kernel, pystac-client, jupyter-events, jupysql, planetary-computer, jupyter-server, geeadd, jupyterlab-server, jupyter-server-proxy, voila, reacton, ipyvue, anywidget, whiteboxgui, mapwidget, ipyvuetify, solara-ui, leafmap, solara-server, solara, pygis
#   Attempting uninstall: jupyter-client
#     Found existing installation: jupyter-client 6.1.12
#     Uninstalling jupyter-client-6.1.12:
#       Successfully uninstalled jupyter-client-6.1.12
#   Attempting uninstall: jupyter-server
#     Found existing installation: jupyter-server 1.16.0
#     Uninstalling jupyter-server-1.16.0:
#       Successfully uninstalled jupyter-server-1.16.0
# Successfully installed anywidget-0.9.18 arrow-1.3.0 backoff-2.2.1 bash_kernel-0.10.0 colorama-0.4.6 duckdb-engine-0.17.0 editorconfig-0.17.1 eval-type-backport-0.2.2 ffmpeg-python-0.2.0 filetype-1.2.0 fqdn-1.5.1 geeadd-1.2.1 geojson-3.2.0 ipyvue-1.11.2 ipyvuetify-1.11.2 isoduration-20.11.0 jedi-0.19.2 jsbeautifier-1.15.4 json5-0.12.0 jupysql-0.11.1 jupysql-plugin-0.4.5 jupyter-client-7.4.9 jupyter-events-0.12.0 jupyter-server-2.16.0 jupyter-server-proxy-4.4.0 jupyter-server-terminals-0.5.3 jupyterlab-server-2.27.3 leafmap-0.48.6 logzero-1.7.0 mapclassify-2.9.0 maplibre-0.3.4 mapwidget-0.2.0 overrides-7.7.0 planetary-computer-1.0.0 ploomber-core-0.2.26 pmtiles-3.4.1 posthog-6.0.0 psygnal-0.13.0 pygis-0.10.1 pymdown-extensions-10.16 pystac-1.13.0 pystac-client-0.8.6 python-dotenv-1.1.1 python-json-logger-3.3.0 reacton-1.9.1 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 rich-click-1.8.9 simpervisor-1.0.0 solara-1.49.0 solara-server-1.49.0 solara-ui-1.49.0 types-python-dateutil-2.9.0.20250516 uri-template-1.3.0 voila-0.5.8 voila-topbar-0.1.1 watchdog-6.0.0 watchfiles-1.1.0 whitebox-2.3.6 whiteboxgui-2.3.0

# %% [markdown]
# ### Importing Libraries and Configuration

# %%
import matplotlib.pyplot as plt
import numpy as np
import xarray as xr

# Configure Xarray for better display and performance
xr.set_options(keep_attrs=True, display_expand_data=False)

# Configure NumPy display for cleaner output
np.set_printoptions(threshold=10, edgeitems=2)

# Configure matplotlib for better plots
plt.rcParams["figure.dpi"] = 150

# %% [markdown]
# ## Loading and Exploring Real Climate Data
#
# ### Loading Tutorial Data

# %%
# Load a climate dataset with air temperature measurements
ds = xr.tutorial.open_dataset("air_temperature")
ds
# Out:
# <xarray.Dataset> Size: 31MB
# Dimensions:  (lat: 25, time: 2920, lon: 53)
# Coordinates:
#   * lat      (lat) float32 100B 75.0 72.5 70.0 67.5 65.0 ... 22.5 20.0 17.5 15.0
#   * lon      (lon) float32 212B 200.0 202.5 205.0 207.5 ... 325.0 327.5 330.0
#   * time     (time) datetime64[ns] 23kB 2013-01-01 ... 2014-12-31T18:00:00
# Data variables:
#     air      (time, lat, lon) float64 31MB ...
# Attributes:
#     Conventions:  COARDS
#     title:        4x daily NMC reanalysis (1948)
#     description:  Data is from NMC initialized reanalysis\n(4x/day).  These a...
#     platform:     Model
#     references:   http://www.esrl.noaa.gov/psd/data/gridded/data.ncep.reanaly...

# %% [markdown]
# ## Working with DataArrays
#
# ### Accessing DataArrays from Datasets

# %%
# Extract the air temperature DataArray using dictionary notation
temperature = ds["air"]
temperature
# Out:
# <xarray.DataArray 'air' (time: 2920, lat: 25, lon: 53)> Size: 31MB
# [3869000 values with dtype=float64]
# Coordinates:
#   * lat      (lat) float32 100B 75.0 72.5 70.0 67.5 65.0 ... 22.5 20.0 17.5 15.0
#   * lon      (lon) float32 212B 200.0 202.5 205.0 207.5 ... 325.0 327.5 330.0
#   * time     (time) datetime64[ns] 23kB 2013-01-01 ... 2014-12-31T18:00:00
# Attributes:
#     long_name:     4xDaily Air temperature at sigma level 995
#     units:         degK
#     precision:     2
#     GRIB_id:       11
#     GRIB_name:     TMP
#     var_desc:      Air temperature
#     dataset:       NMC Reanalysis
#     level_desc:    Surface
#     statistic:     Individual Obs
#     parent_stat:   Other
#     actual_range:  [185.16 322.1 ]

# %%
# Same result using attribute access
temperature = ds.air
temperature
# Out:
# <xarray.DataArray 'air' (time: 2920, lat: 25, lon: 53)> Size: 31MB
# [3869000 values with dtype=float64]
# Coordinates:
#   * lat      (lat) float32 100B 75.0 72.5 70.0 67.5 65.0 ... 22.5 20.0 17.5 15.0
#   * lon      (lon) float32 212B 200.0 202.5 205.0 207.5 ... 325.0 327.5 330.0
#   * time     (time) datetime64[ns] 23kB 2013-01-01 ... 2014-12-31T18:00:00
# Attributes:
#     long_name:     4xDaily Air temperature at sigma level 995
#     units:         degK
#     precision:     2
#     GRIB_id:       11
#     GRIB_name:     TMP
#     var_desc:      Air temperature
#     dataset:       NMC Reanalysis
#     level_desc:    Surface
#     statistic:     Individual Obs
#     parent_stat:   Other
#     actual_range:  [185.16 322.1 ]

# %% [markdown]
# ### Exploring DataArray Components

# %%
# Examine the actual data values (a NumPy array)
print("Data shape:", temperature.values.shape)
print("Data type:", temperature.values.dtype)
print("First few values:", temperature.values.flat[:5])

# %%
# Understand the dimension structure
print("Dimensions:", temperature.dims)
print("Dimension sizes:", temperature.sizes)

# %%
# Explore the coordinate information
print("Coordinates:")
for name, coord in temperature.coords.items():
    print(f"  {name}: {coord.values[:3]}... (showing first 3 values)")

# %%
# Examine metadata attributes
print("Attributes:")
for key, value in temperature.attrs.items():
    print(f"  {key}: {value}")

# %% [markdown]
# ## Intuitive Data Selection and Indexing
#
# ### Label-Based Selection

# %%
# Select data for a specific date and location
point_data = temperature.sel(time="2013-01-01", lat=40.0, lon=260.0)
point_data

# %% [markdown]
# ### Time Range Selection

# %%
# Select all data for January 2013
january_data = temperature.sel(time=slice("2013-01-01", "2013-01-31"))
print(f"January 2013 data shape: {january_data.shape}")
print(f"Time range: {january_data.time.values[0]} to {january_data.time.values[-1]}")

# %% [markdown]
# ### Nearest Neighbor Selection

# %%
# Select data nearest to a location that might not be exactly on the grid
nearest_data = temperature.sel(lat=40.5, lon=255.7, method="nearest")
actual_coords = nearest_data.sel(time="2013-01-01")
print(f"Requested: lat=40.5, lon=255.7")
print(f"Actual: lat={actual_coords.lat.values}, lon={actual_coords.lon.values}")

# %% [markdown]
# ## Performing Operations on Multi-Dimensional Data
#
# ### Statistical Operations Across Dimensions

# %%
# Calculate the temporal mean (average temperature at each location)
mean_temperature = temperature.mean(dim="time")
print(f"Original data shape: {temperature.shape}")
print(f"Time-averaged data shape: {mean_temperature.shape}")
print(
    f"Temperature range: {mean_temperature.min().values:.1f} to {mean_temperature.max().values:.1f} K"
)

# %% [markdown]
# ### Computing Anomalies

# %%
# Calculate temperature anomalies by subtracting the time mean from each time step
anomalies = temperature - mean_temperature
print(f"Anomaly range: {anomalies.min().values:.1f} to {anomalies.max().values:.1f} K")

# Find the location and time of the largest positive anomaly
max_anomaly = anomalies.max()
max_location = anomalies.where(anomalies == max_anomaly, drop=True)
print(f"Largest positive anomaly: {max_anomaly.values:.1f} K")

# %% [markdown]
# ### Spatial Statistics

# %%
# Calculate area-weighted spatial mean for each time step
spatial_mean = temperature.mean(dim=["lat", "lon"])
print(f"Spatial mean temperature time series shape: {spatial_mean.shape}")

# Find the warmest and coldest time periods
warmest_date = spatial_mean.time[spatial_mean.argmax()]
coldest_date = spatial_mean.time[spatial_mean.argmin()]
print(f"Warmest period: {warmest_date.values}")
print(f"Coldest period: {coldest_date.values}")

# %% [markdown]
# ## Data Visualization with Xarray
#
# ### Plotting 2D Spatial Data

# %%
# Create a map of long-term average temperature
fig, ax = plt.subplots(figsize=(12, 6))
mean_temperature.plot(ax=ax, cmap="RdYlBu_r", add_colorbar=True)
plt.title("Long-term Average Air Temperature", fontsize=14, fontweight="bold")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Customizing Spatial Plots

# %%
# Create a more customized visualization
fig, ax = plt.subplots(figsize=(12, 6))
plot = mean_temperature.plot(
    ax=ax,
    cmap="RdYlBu_r",
    levels=20,  # Number of contour levels
    add_colorbar=True,
    cbar_kwargs={"label": "Temperature (K)", "shrink": 0.8, "pad": 0.02},
)
plt.title("Mean Air Temperature (2013)", fontsize=16, fontweight="bold")
plt.xlabel("Longitude (°E)", fontsize=12)
plt.ylabel("Latitude (°N)", fontsize=12)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Time Series Visualization

# %%
# Select and plot time series for a specific location
location_ts = temperature.sel(lat=40.0, lon=260.0)

fig, ax = plt.subplots(figsize=(12, 6))
location_ts.plot(ax=ax, linewidth=1.5, color="darkblue")
plt.title("Temperature Time Series at 40°N, 260°E", fontsize=14, fontweight="bold")
plt.xlabel("Time")
plt.ylabel("Temperature (K)")
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Working with Datasets: Multiple Variables
#
# ### Exploring Dataset Structure

# %%
# Examine all variables in the dataset
print("Data variables in the dataset:")
for var_name, var_info in ds.data_vars.items():
    print(f"  {var_name}: {var_info.dims}, shape {var_info.shape}")

print(f"\nShared coordinates: {list(ds.coords.keys())}")
print(f"Global attributes: {len(ds.attrs)} metadata items")

# %% [markdown]
# ### Dataset-Level Operations

# %%
# Calculate temporal statistics for all variables in the dataset
dataset_means = ds.mean(dim="time")
dataset_means

# %% [markdown]
# ## The Power of Label-Based Operations
#
# ### The NumPy Approach: Index-Based Selection

# %%
# Extract raw arrays and coordinates
lat_values = ds.air.lat.values
lon_values = ds.air.lon.values
temp_values = ds.air.values

print(f"Data shape: {temp_values.shape}")
print("To plot the first time step, you need to remember:")
print("- Time is dimension 0")
print("- Latitude is dimension 1")
print("- Longitude is dimension 2")

# %%
# Plot using NumPy approach - requires careful index management
fig, ax = plt.subplots(figsize=(12, 6))
im = ax.pcolormesh(lon_values, lat_values, temp_values[0, :, :], cmap="RdYlBu_r")
plt.colorbar(im, ax=ax, label="Temperature (K)")
plt.title("First Time Step (NumPy approach)")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.show()

# %% [markdown]
# ### The Xarray Approach: Label-Based Selection

# %%
# Same result with Xarray - much more readable and less error-prone
ds.air.isel(time=0).plot(figsize=(12, 6), cmap="RdYlBu_r")
plt.title("First Time Step (Xarray approach)")
plt.show()

# %%
# Select by actual date rather than array index
ds.air.sel(time="2013-01-01T00:00:00").plot(figsize=(12, 6), cmap="RdYlBu_r")
plt.title("Temperature on January 1, 2013")
plt.show()

# %% [markdown]
# ## Advanced Indexing Techniques
#
# ### Position-Based vs. Label-Based Indexing

# %%
# Position-based indexing using isel() - useful for systematic sampling
first_last_times = ds.air.isel(time=[0, -1])  # First and last time steps
print(f"Selected time steps: {first_last_times.time.values}")

# Label-based indexing using sel() - useful for specific values
specific_months = ds.air.sel(time=slice("2013-05", "2013-07"))
print(f"May-July 2013 contains {len(specific_months.time)} time steps")

# %% [markdown]
# ### Boolean Indexing and Conditional Selection

# %%
# Find locations where average temperature exceeds a threshold
warm_locations = mean_temperature.where(mean_temperature > 280)  # 280 K ≈ 7°C
warm_count = warm_locations.count()
print(f"Number of grid points with mean temperature > 280 K: {warm_count.values}")

# Find time periods when spatial average temperature was unusually high
temp_threshold = spatial_mean.quantile(0.9)  # 90th percentile
warm_periods = spatial_mean.where(spatial_mean > temp_threshold, drop=True)
print(f"Number of exceptionally warm time periods: {len(warm_periods)}")

# %% [markdown]
# ## High-Level Computational Operations
#
# ### GroupBy Operations for Temporal Analysis

# %%
# Calculate seasonal climatology
seasonal_means = ds.air.groupby("time.season").mean()
print("Seasonal temperature patterns:")
seasonal_means

# %%
# Visualize seasonal patterns
fig, axes = plt.subplots(2, 2, figsize=(12, 6))
seasons = ["DJF", "MAM", "JJA", "SON"]
season_names = ["Winter", "Spring", "Summer", "Fall"]

for i, (season, name) in enumerate(zip(seasons, season_names)):
    ax = axes[i // 2, i % 2]
    seasonal_means.sel(season=season).plot(ax=ax, cmap="RdYlBu_r", add_colorbar=False)
    ax.set_title(f"{name} ({season})")
    ax.set_xlabel("Longitude")
    ax.set_ylabel("Latitude")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Rolling Window Operations

# %%
# Create a smoothed time series using a rolling window
location_data = temperature.sel(lat=40.0, lon=260.0)

fig, ax = plt.subplots(figsize=(12, 6))

# Plot original data
location_data.plot(ax=ax, alpha=0.5, label="Original", color="lightblue")

# Plot smoothed data using a 30-day rolling window
smoothed_data = location_data.rolling(time=30, center=True).mean()
smoothed_data.plot(ax=ax, label="30-day smoothed", color="darkblue", linewidth=2)

plt.title("Temperature Time Series: Original vs Smoothed")
plt.xlabel("Time")
plt.ylabel("Temperature (K)")
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Weighted Operations

# %%
# Create simple area weights (this is a simplified example)
# In practice, you would use proper latitude-based area weighting
lat_weights = np.cos(np.radians(ds.air.lat))
area_weighted_mean = ds.air.weighted(lat_weights).mean(dim=["lat", "lon"])

# Compare simple vs area-weighted spatial averages
fig, ax = plt.subplots(figsize=(12, 6))
spatial_mean.plot(ax=ax, label="Simple average", alpha=0.7)
area_weighted_mean.plot(ax=ax, label="Area-weighted average", linewidth=2)
plt.title("Spatial Temperature Averages: Simple vs Area-Weighted")
plt.xlabel("Time")
plt.ylabel("Temperature (K)")
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Data Input and Output
#
# ### Understanding NetCDF Format
#
# ### Writing Data to NetCDF

# %%
# Prepare data for saving (ensure proper data types)
output_ds = ds.copy()
output_ds["air"] = output_ds["air"].astype("float32")  # Reduce file size

# Add processing metadata
output_ds.attrs["processing_date"] = str(np.datetime64("now"))
output_ds.attrs["created_by"] = "GIS Pro"

# Save to NetCDF file
output_ds.to_netcdf("processed_air_temperature.nc")
print("Dataset saved to processed_air_temperature.nc")

# %% [markdown]
# ### Reading Data from NetCDF

# %%
# Load the saved dataset
reloaded_ds = xr.open_dataset("processed_air_temperature.nc")
print("Successfully reloaded dataset:")
print(f"Variables: {list(reloaded_ds.data_vars.keys())}")
print(f"Processing date: {reloaded_ds.attrs.get('processing_date', 'Not specified')}")
print(f"Data matches original: {reloaded_ds.air.equals(ds.air.astype('float32'))}")

# %% [markdown]
# ## Key Takeaways
#
# ## Further Reading
#
# ## Exercises
#
# ### Exercise 1: Exploring a New Dataset

# %% [markdown]
# ### Exercise 2: Data Selection and Indexing

# %% [markdown]
# ### Exercise 3: Performing Arithmetic Operations

# %% [markdown]
# ### Exercise 4: GroupBy and Temporal Analysis

# %% [markdown]
# ### Exercise 5: Data Storage and Retrieval
